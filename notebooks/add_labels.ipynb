# %%
from pathlib import Path
import sys, sqlite3, pandas as pd
from IPython.display import display, Markdown

# Текущая рабочая директория Jupyter
cwd = Path.cwd()

# Если CWD = Project/notebooks, то корень проекта = parent
project_root = cwd.parent

# Добавляем корень проекта в sys.path (в начало, чтобы он имел приоритет)
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

pd.set_option("display.width", 2000)     # максимальная ширина в символах
pd.set_option("display.max_colwidth", None)

from config import DB_PATH, PARQUETS_DIR
from processing_cpp import normalize_includes
from lf_functions import LFS

# %%
with sqlite3.connect(DB_PATH) as conn:
    recommendations = pd.read_sql_query("""
                                        SELECT ec.error_code, r.recommendation_id, r.recommendation, r.recommendation_code
                                        FROM error_codes ec
                                        JOIN recommendations r ON r.error_code_id = ec.error_code_id
                                        WHERE r.is_active = 1
                                        ORDER BY ec.error_code, r.recommendation_id
                                        """, conn)

# %%
default_recommendations = (
    recommendations
    .sort_values(['error_code', 'recommendation_id'])
    .groupby('error_code', as_index=False)
    .first()
)

# %%
code_to_label_code = dict(zip(default_recommendations['error_code'], default_recommendations['recommendation_code']))

# %%
df = pd.read_parquet(PARQUETS_DIR / "data_filtered_error_codes.parquet")

# %%
df['label_code'] = df['error_code'].map(code_to_label_code)

# %%
def add_line_numbers(code : str) -> str:
    if not isinstance(code, str):
        return code

    lines = code.split('\n')
    if not lines:
        return code

    width = len(str(len(lines)))
    numbered = [
        f"{i:>{width}d} | {line}"
        for i, line in enumerate(lines, start=1)
    ]
    return "\n".join(numbered)

def show_table(df : pd.DataFrame, mask : pd.Series | None = None, rows = None):
    subset = df if mask is None else df[mask]
    print(len(subset))
    
    cols = ['label_code', 'error_text', 'is_in_train', 'error_line', 'source_code']

    subset = subset.copy()
    subset['label_code'] = subset['label_code'].astype(str)
    subset['is_in_train'] = subset['is_in_train'].astype(str)
    subset['source_code'] = subset['source_code'].apply(normalize_includes)
    subset['source_code'] = subset['source_code'].str.replace('\\n', '\n')
    subset['source_code'] = subset['source_code'].apply(add_line_numbers)

    if rows is not None:
        if isinstance(rows, slice):
            subset = subset.iloc[rows]
        else:
            subset = subset.loc[rows]
    styler = subset[cols].style.format(escape="html")

    styler = styler.set_table_styles([
        {
            'selector': 'th, td',
            'props': [('text-align', 'left')],
        },
        {
            'selector': 'td',
            'props': [
                ('max-width', 'none'),
                ('overflow', 'visible'),
            ],
        },
    ])
    styler = styler.set_properties(
        subset=['source_code'],
        **{
            'white-space': 'pre',
            'font-family': 'monospace',
        }
    )
    styler = styler.set_properties(
        subset=['label_code', 'error_text', 'is_in_train', 'error_line'],
        **{
            'font-family': 'sans-serif',
        }
    )
    return styler

def show_row(df : pd.DataFrame, i : int) -> None:
    row = df.loc[i]
    src = normalize_includes(row['source_code']).replace('\\n', '\n') # type: ignore
    src = add_line_numbers(src)

    md = (
        f"### Row {i}\n"
        f"**label_code**: `{row.get('label_code', '')}`  \n\n"
        f"**is_in_train**: `{row['is_in_train']}`  \n\n"
        f"**error_text**:\n"
        f"`{row['error_text']}`\n\n"
        f"**error_line**:\n"
        f"`{row['error_line']}`\n\n"
        f"```cpp\n"
        f"{src}\n"
        f"```\n"
    )
    display(Markdown(md))

# %%
def apply_labeling_functions(df : pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    def apply_row(row : pd.Series):
        suggestions = []
        for lf in LFS:
            code = lf(row)
            if code is not None:
                suggestions.append(code)

        if not suggestions:
            return row['label_code']

        if len(set(suggestions)) == 1:
            # Все ЛФ согласились
            return suggestions[0]

        # print(f"Conflict")
        return suggestions[-1]

    df['label_code'] = df.apply(apply_row, axis=1)
    return df

# %%
df_slice = df[(df["error_code"] == "C2146") & df["is_in_train"] == 1].iloc[300:400]

# %%
new_df = apply_labeling_functions(df)

# %%
# show_row(df, 137930)

# %%
pattern = r"(?m)^(?!\s*#include\s*<).*?\b(?:[A-Za-z_]\w*(?:::\w+)*)\s*<\s*[A-Za-z_:\w,\s]+>"
# mask1 = df["error_code"] == "C2146"
mask2 = (new_df["error_code"] == "C2146") & new_df["is_in_train"] == 1
show_table(new_df, mask2, slice(0, 20000, 100))

# %%
msk1 = (new_df["error_code"] == "C2146") & (new_df["label_code"] == "INCORRECT_CONSTRUCTION_OR_SYMBOLS") & new_df["is_in_train"] == 1
show_table(new_df, msk1, slice(2, 60))
# Out:
# 472
# <style type="text/css">
# #T_b7e95 th {
#   text-align: left;
# }
# #T_b7e95  td {
#   text-align: left;
# }
# #T_b7e95 td {
#   max-width: none;
#   overflow: visible;
# }
# #T_b7e95_row0_col0, #T_b7e95_row0_col1, #T_b7e95_row0_col2, #T_b7e95_row0_col3, #T_b7e95_row1_col0, #T_b7e95_row1_col1, #T_b7e95_row1_col2, #T_b7e95_row1_col3, #T_b7e95_row2_col0, #T_b7e95_row2_col1, #T_b7e95_row2_col2, #T_b7e95_row2_col3, #T_b7e95_row3_col0, #T_b7e95_row3_col1, #T_b7e95_row3_col2, #T_b7e95_row3_col3, #T_b7e95_row4_col0, #T_b7e95_row4_col1, #T_b7e95_row4_col2, #T_b7e95_row4_col3, #T_b7e95_row5_col0, #T_b7e95_row5_col1, #T_b7e95_row5_col2, #T_b7e95_row5_col3, #T_b7e95_row6_col0, #T_b7e95_row6_col1, #T_b7e95_row6_col2, #T_b7e95_row6_col3, #T_b7e95_row7_col0, #T_b7e95_row7_col1, #T_b7e95_row7_col2, #T_b7e95_row7_col3, #T_b7e95_row8_col0, #T_b7e95_row8_col1, #T_b7e95_row8_col2, #T_b7e95_row8_col3, #T_b7e95_row9_col0, #T_b7e95_row9_col1, #T_b7e95_row9_col2, #T_b7e95_row9_col3, #T_b7e95_row10_col0, #T_b7e95_row10_col1, #T_b7e95_row10_col2, #T_b7e95_row10_col3, #T_b7e95_row11_col0, #T_b7e95_row11_col1, #T_b7e95_row11_col2, #T_b7e95_row11_col3, #T_b7e95_row12_col0, #T_b7e95_row12_col1, #T_b7e95_row12_col2, #T_b7e95_row12_col3, #T_b7e95_row13_col0, #T_b7e95_row13_col1, #T_b7e95_row13_col2, #T_b7e95_row13_col3, #T_b7e95_row14_col0, #T_b7e95_row14_col1, #T_b7e95_row14_col2, #T_b7e95_row14_col3, #T_b7e95_row15_col0, #T_b7e95_row15_col1, #T_b7e95_row15_col2, #T_b7e95_row15_col3, #T_b7e95_row16_col0, #T_b7e95_row16_col1, #T_b7e95_row16_col2, #T_b7e95_row16_col3, #T_b7e95_row17_col0, #T_b7e95_row17_col1, #T_b7e95_row17_col2, #T_b7e95_row17_col3, #T_b7e95_row18_col0, #T_b7e95_row18_col1, #T_b7e95_row18_col2, #T_b7e95_row18_col3, #
# }
# #T_b7e95_row0_col4, #T_b7e95_row1_col4, #T_b7e95_row2_col4, #T_b7e95_row3_col4, #T_b7e95_row4_col4, #T_b7e95_row5_col4, #T_b7e95_row6_col4, #T_b7e95_row7_col4, #T_b7e95_row8_col4, #T_b7e95_row9_col4, #T_b7e95_row10_col4, #T_b7e95_row11_col4, #T_b7e95_row12_col4, #T_b7e95_row13_col4, #T_b7e95_row14_col4, #T_b7e95_row15_col4, #T_b7e95_row16_col4, #T_b7e95_row17_col4, #T_b7e95_row18_col4, #T_b7e95_row19_col4, #T_b7e95_row20_col4, #T_b7e95_row21_col4, #T_b7e95_row22_col4, #T_b7e95_row23_col4, #T_b7e95_row24_col4, #T_b7e95_row25_col4, #T_b7e95_row26_col4, #T_b7e95_row27_col4, #T_b7e95_row28_col4, #T_b7e95_row29_col4, #T_b7e95_row30_col4, #T_b7e95_row31_col4, #T_b7e95_row32_col4, #T_b7e95_row33_col4, #T_b7e95_row34_col4, #T_b7e95_row35_col4, #T_b7e95_row36_col4, #T_b7e95_row37_col4, #T_b7e95_row38_col4, #T_b7e95_row39_col4, #T_b7e95_row40_col4, #T_b7e95_row41_col4, #T_b7e95_row42_col4, #T_b7e95_row43_col4, #T_b7e95_row44_col4, #T_b7e95_row45_col4, #T_b7e95_row46_col4, #T_b7e95_row47_col4, #T_b7e95_row48_col4, #T_b7e95_row49_col4, #T_b7e95_row50_col4, #T_b7e95_row51_col4, #T_b7e95_row52_col4, #T_b7e95_row53_col4, #T_b7e95_row54_col4, #T_b7e95_row55_col4, #T_b7e95_row56_col4, #T_b7e95_row57_col4 {
#   white-space: pre;
#   font-family: monospace;
# }
# </style>
# <table id="T_b7e95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7e95_level0_col0" class="col_heading level0 col0" >label_code</th>
#       <th id="T_b7e95_level0_col1" class="col_heading level0 col1" >error_text</th>
#       <th id="T_b7e95_level0_col2" class="col_heading level0 col2" >is_in_train</th>
#       <th id="T_b7e95_level0_col3" class="col_heading level0 col3" >error_line</th>
#       <th id="T_b7e95_level0_col4" class="col_heading level0 col4" >source_code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7e95_level0_row0" class="row_heading level0 row0" >472</th>
#       <td id="T_b7e95_row0_col0" class="data row0 col0" >INCORRECT_CONSTRUCTION_OR_SYMBOLS</td>
#       <td id="T_b7e95_row0_col1" class="data row0 col1" >C2146: синтаксическая ошибка: отсутствие &#34;;&#34; перед идентификатором &#34;j&#34;</td>
#       <td id="T_b7e95_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_b7e95_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_b7e95_row0_col4" class="data row0 col4" > 1 | #include &lt;stdio.h&gt;
#  2 |
#  3 | int main(void) {
#  4 | 	for (int i = 0; i &lt;= 9; i++) {
#  5 | 		for (int j = 0 j &lt;= 9; j++) {
#  6 | 			printf(&#34;%dx%d=%d
#  7 | &#34;, i, j, i*j);
#  8 | 		}
#  9 | 	}
# 10 | 	return 0;
# 11 | }</td>
#     </tr>
#     <tr>
#       <th id="T_b7e95_level0_row1" class="row_heading level0 row1" >662</th>
#       <td id="T_b7e95_row1_col0" class="data row1 col0" >INCORRECT_CONSTRUCTION_OR_SYMBOLS</td>
#       <td id="T_b7e95_row1_col1" class="data row1 col1" >C2146: синтаксическая ошибка: отсутствие &#34;;&#34; перед идентификатором &#34;i&#34;</td>
#       <td id="T_b7e95_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_b7e95_row
